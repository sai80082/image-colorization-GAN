# %% [markdown]
# # importing libraries

# %%
from PIL import Image
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from matplotlib import image
from matplotlib import pyplot as plt
import os
from tensorflow import keras

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

# %% [markdown]
# ## loading data

# %%
batch_size = 4
img_size = 120
dataset_split = 2500
master_dir = 'data/'

# %%
x = []
y = []
for image_file in os.listdir( master_dir )[ 0 : 2500 ]:
    rgb_image = Image.open( os.path.join( master_dir , image_file ) ).resize( ( img_size , img_size ) )
    # Normalize the RGB image array
    rgb_img_array = (np.asarray( rgb_image ) ) / 255
    gray_image = rgb_image.convert( 'L' )
    # Normalize the grayscale image array
    gray_img_array = ( np.asarray( gray_image ).reshape( ( img_size , img_size , 1 ) ) ) / 255
    # Append both the image arrays
    x.append( gray_img_array )
    y.append( rgb_img_array )

# Train-test splitting
train_x, test_x, train_y, test_y = train_test_split( np.array(x) , np.array(y) , test_size=0.1 )

# Construct tf.data.Dataset object
# Manually create batches
train_dataset = []
for i in range(0, len(train_x), batch_size):
    batch_x = train_x[i:i+batch_size]
    batch_y = train_y[i:i+batch_size]
    train_dataset.append((batch_x, batch_y))

# %% [markdown]
# ## Models

# %% [markdown]
# ### Generator

# %%
def get_generator_model():

    inputs = tf.keras.layers.Input( shape=( img_size , img_size , 1 ) )

    conv1 = tf.keras.layers.Conv2D( 16 , kernel_size=( 5 , 5 ) , strides=1 )( inputs )
    conv1 = tf.keras.layers.LeakyReLU()( conv1 )
    conv1 = tf.keras.layers.Conv2D( 32 , kernel_size=( 3 , 3 ) , strides=1)( conv1 )
    conv1 = tf.keras.layers.LeakyReLU()( conv1 )
    conv1 = tf.keras.layers.Conv2D( 32 , kernel_size=( 3 , 3 ) , strides=1)( conv1 )
    conv1 = tf.keras.layers.LeakyReLU()( conv1 )

    conv2 = tf.keras.layers.Conv2D( 32 , kernel_size=( 5 , 5 ) , strides=1)( conv1 )
    conv2 = tf.keras.layers.LeakyReLU()( conv2 )
    conv2 = tf.keras.layers.Conv2D( 64 , kernel_size=( 3 , 3 ) , strides=1 )( conv2 )
    conv2 = tf.keras.layers.LeakyReLU()( conv2 )
    conv2 = tf.keras.layers.Conv2D( 64 , kernel_size=( 3 , 3 ) , strides=1 )( conv2 )
    conv2 = tf.keras.layers.LeakyReLU()( conv2 )

    conv3 = tf.keras.layers.Conv2D( 64 , kernel_size=( 5 , 5 ) , strides=1 )( conv2 )
    conv3 = tf.keras.layers.LeakyReLU()( conv3 )
    conv3 = tf.keras.layers.Conv2D( 128 , kernel_size=( 3 , 3 ) , strides=1 )( conv3 )
    conv3 = tf.keras.layers.LeakyReLU()( conv3 )
    conv3 = tf.keras.layers.Conv2D( 128 , kernel_size=( 3 , 3 ) , strides=1 )( conv3 )
    conv3 = tf.keras.layers.LeakyReLU()( conv3 )

    bottleneck = tf.keras.layers.Conv2D( 128 , kernel_size=( 3 , 3 ) , strides=1 , activation='tanh' , padding='same' )( conv3 )

    concat_1 = tf.keras.layers.Concatenate()( [ bottleneck , conv3 ] )
    conv_up_3 = tf.keras.layers.Conv2DTranspose( 128 , kernel_size=( 3 , 3 ) , strides=1 , activation='relu' )( concat_1 )
    conv_up_3 = tf.keras.layers.Conv2DTranspose( 128 , kernel_size=( 3 , 3 ) , strides=1 , activation='relu' )( conv_up_3 )
    conv_up_3 = tf.keras.layers.Conv2DTranspose( 64 , kernel_size=( 5 , 5 ) , strides=1 , activation='relu' )( conv_up_3 )

    concat_2 = tf.keras.layers.Concatenate()( [ conv_up_3 , conv2 ] )
    conv_up_2 = tf.keras.layers.Conv2DTranspose( 64 , kernel_size=( 3 , 3 ) , strides=1 , activation='relu' )( concat_2 )
    conv_up_2 = tf.keras.layers.Conv2DTranspose( 64 , kernel_size=( 3 , 3 ) , strides=1 , activation='relu' )( conv_up_2 )
    conv_up_2 = tf.keras.layers.Conv2DTranspose( 32 , kernel_size=( 5 , 5 ) , strides=1 , activation='relu' )( conv_up_2 )

    concat_3 = tf.keras.layers.Concatenate()( [ conv_up_2 , conv1 ] )
    conv_up_1 = tf.keras.layers.Conv2DTranspose( 32 , kernel_size=( 3 , 3 ) , strides=1 , activation='relu')( concat_3 )
    conv_up_1 = tf.keras.layers.Conv2DTranspose( 32 , kernel_size=( 3 , 3 ) , strides=1 , activation='relu')( conv_up_1 )
    conv_up_1 = tf.keras.layers.Conv2DTranspose( 3 , kernel_size=( 5 , 5 ) , strides=1 , activation='relu')( conv_up_1 )

    model = tf.keras.models.Model( inputs , conv_up_1 )
    return model

# %% [markdown]
# ### Discriminator

# %%
def get_discriminator_model():
    layers = [
        tf.keras.Input(shape=(120, 120, 3)),
        tf.keras.layers.Conv2D(32, kernel_size=(7, 7), strides=1, activation='relu'),
        tf.keras.layers.Conv2D( 32 , kernel_size=( 7, 7 ) , strides=1, activation='relu'  ),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D( 64 , kernel_size=( 5 , 5 ) , strides=1, activation='relu'  ),
        tf.keras.layers.Conv2D( 64 , kernel_size=( 5 , 5 ) , strides=1, activation='relu'  ),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D( 128 , kernel_size=( 3 , 3 ) , strides=1, activation='relu'  ),
        tf.keras.layers.Conv2D( 128 , kernel_size=( 3 , 3 ) , strides=1, activation='relu'  ),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D( 256 , kernel_size=( 3 , 3 ) , strides=1, activation='relu'  ),
        tf.keras.layers.Conv2D( 256 , kernel_size=( 3 , 3 ) , strides=1, activation='relu'  ),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense( 512, activation='relu'  )  ,
        tf.keras.layers.Dense( 128 , activation='relu' ) ,
        tf.keras.layers.Dense( 16 , activation='relu' ) ,
        tf.keras.layers.Dense( 1 , activation='sigmoid' ) 
    ]
    model = tf.keras.models.Sequential( layers )
    return model

# %% [markdown]
# ## loss functions

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()
mse = tf.keras.losses.MeanSquaredError()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output) - tf.random.uniform( shape=real_output.shape , maxval=0.1 ) , real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output) + tf.random.uniform( shape=fake_output.shape , maxval=0.1  ) , fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output , real_y):
    real_y = tf.cast( real_y , 'float32' )
    return mse( fake_output , real_y )

generator_optimizer = tf.keras.optimizers.Adam( 0.0005 )
discriminator_optimizer = tf.keras.optimizers.Adam( 0.0005 )

generator = get_generator_model()
discriminator = get_discriminator_model()

# %%
generator.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 120, 120,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 116, 116,  │        416 │ input_layer_2[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 116, 116,  │          0 │ conv2d_18[0][0]   │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 114, 114,  │      4,640 │ leaky_re_lu_9[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 114, 114,  │          0 │ conv2d_19[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 112, 112,  │      9,248 │ leaky_re_lu_10[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 112, 112,  │          0 │ conv2d_20[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 108, 108,  │     25,632 │ leaky_re_lu_11[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 108, 108,  │          0 │ conv2d_21[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 106, 106,  │     18,496 │ leaky_re_lu_12[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 106, 106,  │          0 │ conv2d_22[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 104, 104,  │     36,928 │ leaky_re_lu_13[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 104, 104,  │          0 │ conv2d_23[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 100, 100,  │    102,464 │ leaky_re_lu_14[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 100, 100,  │          0 │ conv2d_24[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 98, 98,    │     73,856 │ leaky_re_lu_15[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 98, 98,    │          0 │ conv2d_25[0][0]   │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 96, 96,    │    147,584 │ leaky_re_lu_16[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_17      │ (None, 96, 96,    │          0 │ conv2d_26[0][0]   │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 96, 96,    │    147,584 │ leaky_re_lu_17[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 96, 96,    │          0 │ conv2d_27[0][0],  │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_17[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_9  │ (None, 98, 98,    │    295,040 │ concatenate_3[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_10 │ (None, 100, 100,  │    147,584 │ conv2d_transpose… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_11 │ (None, 104, 104,  │    204,864 │ conv2d_transpose… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 104, 104,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_14[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_12 │ (None, 106, 106,  │     73,792 │ concatenate_4[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_13 │ (None, 108, 108,  │     36,928 │ conv2d_transpose… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_14 │ (None, 112, 112,  │     51,232 │ conv2d_transpose… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 112, 112,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_15 │ (None, 114, 114,  │     18,464 │ concatenate_5[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_16 │ (None, 116, 116,  │      9,248 │ conv2d_transpose… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_17 │ (None, 120, 120,  │      2,403 │ conv2d_transpose… │
# │ (Conv2DTranspose)   │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,406,403 (5.37 MB)
#  Trainable params: 1,406,403 (5.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
discriminator.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_28 (Conv2D)              │ (None, 114, 114, 32)   │         4,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_29 (Conv2D)              │ (None, 108, 108, 32)   │        50,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_30 (Conv2D)              │ (None, 50, 50, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_31 (Conv2D)              │ (None, 46, 46, 64)     │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (None, 21, 21, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 19, 19, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 9, 9, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 7, 7, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 5, 5, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │         2,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,907,905 (7.28 MB)
#  Trainable params: 1,907,905 (7.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## training

# %%
@tf.function
def train_step( input_x , real_y ):
   
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator( input_x , training=True)
        real_output = discriminator( real_y, training=True)
        generated_output = discriminator(generated_images, training=True)
        gen_loss = generator_loss( generated_images , real_y )
        disc_loss = discriminator_loss( real_output, generated_output )

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

# %%
import time
num_epochs = 200

def get_time():
    return time.strftime("%H:%M:%S", time.localtime())

total_start_time = time.time() 

for e in range(num_epochs):
    epoch_start_time = time.time()  
    print(f"Epoch {e+1}/{num_epochs}, Start Time: {get_time()}")

    for (x, y) in train_dataset:
        train_step(x, y)

    epoch_end_time = time.time()  # Record the end time for the current epoch
    epoch_time = epoch_end_time - epoch_start_time  # Calculate the time taken for the current epoch
    print(f"Epoch {e+1}/{num_epochs}, End Time: {get_time()}, Time Taken: {epoch_time:.2f} seconds")
    
total_end_time = time.time()  # Record the end time for all epochs
total_time = total_end_time - total_start_time  # Calculate the total time taken for all epochs
print(f"Total Time Taken for {num_epochs} epochs: {total_time:.2f} seconds")
# Out:
# Epoch 1/200, Start Time: 13:18:19
# 2024-03-26 13:18:23.556525: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 2024-03-26 13:18:27.423614: W external/local_tsl/tsl/framework/bfc_allocator.cc:368] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2024-03-26 13:18:27.790248: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-26 13:19:06.961306: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.10GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# Epoch 1/200, End Time: 13:19:07, Time Taken: 48.74 seconds
# Epoch 2/200, Start Time: 13:19:07
# Epoch 2/200, End Time: 13:19:41, Time Taken: 33.76 seconds
# Epoch 3/200, Start Time: 13:19:41
# Epoch 3/200, End Time: 13:20:15, Time Taken: 33.84 seconds
# Epoch 4/200, Start Time: 13:20:15
# Epoch 4/200, End Time: 13:20:49, Time Taken: 33.95 seconds
# Epoch 5/200, Start Time: 13:20:49
# Epoch 5/200, End Time: 13:21:23, Time Taken: 33.99 seconds
# Epoch 6/200, Start Time: 13:21:23
# Epoch 6/200, End Time: 13:21:57, Time Taken: 34.06 seconds
# Epoch 7/200, Start Time: 13:21:57
# Epoch 7/200, End Time: 13:22:31, Time Taken: 34.13 seconds
# Epoch 8/200, Start Time: 13:22:31
# Epoch 8/200, End Time: 13:23:05, Time Taken: 34.15 seconds
# Epoch 9/200, Start Time: 13:23:05
# Epoch 9/200, End Time: 13:23:39, Time Taken: 34.18 seconds
# Epoch 10/200, Start Time: 13:23:39
# Epoch 10/200, End Time: 13:24:14, Time Taken: 34.18 seconds
# Epoch 11/200, Start Time: 13:24:14
# Epoch 11/200, End Time: 13:24:48, Time Taken: 34.22 seconds
# Epoch 12/200, Start Time: 13:24:48
# Epoch 12/200, End Time: 13:25:22, Time Taken: 34.24 seconds
# Epoch 13/200, Start Time: 13:25:22
# Epoch 13/200, End Time: 13:25:56, Time Taken: 34.27 seconds
# Epoch 14/200, Start Time: 13:25:56
# Epoch 14/200, End Time: 13:26:31, Time Taken: 34.21 seconds
# Epoch 15/200, Start Time: 13:26:31
# Epoch 15/200, End Time: 13:27:05, Time Taken: 34.29 seconds
# Epoch 16/200, Start Time: 13:27:05
# Epoch 16/200, End Time: 13:27:39, Time Taken: 34.30 seconds
# Epoch 17/200, Start Time: 13:27:39
# Epoch 17/200, End Time: 13:28:13, Time Taken: 34.32 seconds
# Epoch 18/200, Start Time: 13:28:13
# Epoch 18/200, End Time: 13:28:48, Time Taken: 34.27 seconds
# Epoch 19/200, Start Time: 13:28:48
# Epoch 19/200, End Time: 13:29:22, Time Taken: 34.20 seconds
# Epoch 20/200, Start Time: 13:29:22
# Epoch 20/200, End Time: 13:29:56, Time Taken: 34.29 seconds
# Epoch 21/200, Start Time: 13:29:56
# Epoch 21/200, End Time: 13:30:30, Time Taken: 34.26 seconds
# Epoch 22/200, Start Time: 13:30:30
# Epoch 22/200, End Time: 13:31:05, Time Taken: 34.29 seconds
# Epoch 23/200, Start Time: 13:31:05
# Epoch 23/200, End Time: 13:31:39, Time Taken: 34.24 seconds
# Epoch 24/200, Start Time: 13:31:39
# Epoch 24/200, End Time: 13:32:13, Time Taken: 34.27 seconds
# Epoch 25/200, Start Time: 13:32:13
# Epoch 25/200, End Time: 13:32:48, Time Taken: 34.26 seconds
# Epoch 26/200, Start Time: 13:32:48
# Epoch 26/200, End Time: 13:33:22, Time Taken: 34.22 seconds
# Epoch 27/200, Start Time: 13:33:22
# Epoch 27/200, End Time: 13:33:56, Time Taken: 34.28 seconds
# Epoch 28/200, Start Time: 13:33:56
# Epoch 28/200, End Time: 13:34:30, Time Taken: 34.20 seconds
# Epoch 29/200, Start Time: 13:34:30
# Epoch 29/200, End Time: 13:35:04, Time Taken: 34.23 seconds
# Epoch 30/200, Start Time: 13:35:04
# Epoch 30/200, End Time: 13:35:39, Time Taken: 34.19 seconds
# Epoch 31/200, Start Time: 13:35:39
# Epoch 31/200, End Time: 13:36:13, Time Taken: 34.21 seconds
# Epoch 32/200, Start Time: 13:36:13
# Epoch 32/200, End Time: 13:36:47, Time Taken: 34.20 seconds
# Epoch 33/200, Start Time: 13:36:47
# Epoch 33/200, End Time: 13:37:21, Time Taken: 34.20 seconds
# Epoch 34/200, Start Time: 13:37:21
# Epoch 34/200, End Time: 13:37:55, Time Taken: 34.21 seconds
# Epoch 35/200, Start Time: 13:37:55
# Epoch 35/200, End Time: 13:38:30, Time Taken: 34.18 seconds
# Epoch 36/200, Start Time: 13:38:30
# Epoch 36/200, End Time: 13:39:04, Time Taken: 34.22 seconds
# Epoch 37/200, Start Time: 13:39:04
# Epoch 37/200, End Time: 13:39:38, Time Taken: 34.25 seconds
# Epoch 38/200, Start Time: 13:39:38
# Epoch 38/200, End Time: 13:40:12, Time Taken: 34.26 seconds
# Epoch 39/200, Start Time: 13:40:12
# Epoch 39/200, End Time: 13:40:47, Time Taken: 34.26 seconds
# Epoch 40/200, Start Time: 13:40:47
# Epoch 40/200, End Time: 13:41:21, Time Taken: 34.25 seconds
# Epoch 41/200, Start Time: 13:41:21
# Epoch 41/200, End Time: 13:41:55, Time Taken: 34.24 seconds
# Epoch 42/200, Start Time: 13:41:55
# Epoch 42/200, End Time: 13:42:29, Time Taken: 34.25 seconds
# Epoch 43/200, Start Time: 13:42:29
# Epoch 43/200, End Time: 13:43:04, Time Taken: 34.22 seconds
# Epoch 44/200, Start Time: 13:43:04
# Epoch 44/200, End Time: 13:43:38, Time Taken: 34.26 seconds
# Epoch 45/200, Start Time: 13:43:38
# Epoch 45/200, End Time: 13:44:12, Time Taken: 34.24 seconds
# Epoch 46/200, Start Time: 13:44:12
# Epoch 46/200, End Time: 13:44:46, Time Taken: 34.31 seconds
# Epoch 47/200, Start Time: 13:44:46
# Epoch 47/200, End Time: 13:45:21, Time Taken: 34.31 seconds
# Epoch 48/200, Start Time: 13:45:21
# Epoch 48/200, End Time: 13:45:55, Time Taken: 34.28 seconds
# Epoch 49/200, Start Time: 13:45:55
# Epoch 49/200, End Time: 13:46:29, Time Taken: 34.21 seconds
# Epoch 50/200, Start Time: 13:46:29
# Epoch 50/200, End Time: 13:47:04, Time Taken: 34.28 seconds
# Epoch 51/200, Start Time: 13:47:04
# Epoch 51/200, End Time: 13:47:38, Time Taken: 34.29 seconds
# Epoch 52/200, Start Time: 13:47:38
# Epoch 52/200, End Time: 13:48:12, Time Taken: 34.26 seconds
# Epoch 53/200, Start Time: 13:48:12
# Epoch 53/200, End Time: 13:48:46, Time Taken: 34.29 seconds
# Epoch 54/200, Start Time: 13:48:46
# Epoch 54/200, End Time: 13:49:21, Time Taken: 34.27 seconds
# Epoch 55/200, Start Time: 13:49:21
# Epoch 55/200, End Time: 13:49:55, Time Taken: 34.28 seconds
# Epoch 56/200, Start Time: 13:49:55
# Epoch 56/200, End Time: 13:50:29, Time Taken: 34.27 seconds
# Epoch 57/200, Start Time: 13:50:29
# Epoch 57/200, End Time: 13:51:03, Time Taken: 34.27 seconds
# Epoch 58/200, Start Time: 13:51:03
# Epoch 58/200, End Time: 13:51:38, Time Taken: 34.28 seconds
# Epoch 59/200, Start Time: 13:51:38
# Epoch 59/200, End Time: 13:52:12, Time Taken: 34.29 seconds
# Epoch 60/200, Start Time: 13:52:12
# Epoch 60/200, End Time: 13:52:46, Time Taken: 34.28 seconds
# Epoch 61/200, Start Time: 13:52:46
# Epoch 61/200, End Time: 13:53:21, Time Taken: 34.29 seconds
# Epoch 62/200, Start Time: 13:53:21
# Epoch 62/200, End Time: 13:53:55, Time Taken: 34.28 seconds
# Epoch 63/200, Start Time: 13:53:55
# Epoch 63/200, End Time: 13:54:29, Time Taken: 34.27 seconds
# Epoch 64/200, Start Time: 13:54:29
# Epoch 64/200, End Time: 13:55:03, Time Taken: 34.28 seconds
# Epoch 65/200, Start Time: 13:55:03
# Epoch 65/200, End Time: 13:55:38, Time Taken: 34.27 seconds
# Epoch 66/200, Start Time: 13:55:38
# Epoch 66/200, End Time: 13:56:12, Time Taken: 34.25 seconds
# Epoch 67/200, Start Time: 13:56:12
# Epoch 67/200, End Time: 13:56:46, Time Taken: 34.28 seconds
# Epoch 68/200, Start Time: 13:56:46
# Epoch 68/200, End Time: 13:57:20, Time Taken: 34.24 seconds
# Epoch 69/200, Start Time: 13:57:20
# Epoch 69/200, End Time: 13:57:55, Time Taken: 34.23 seconds
# Epoch 70/200, Start Time: 13:57:55
# Epoch 70/200, End Time: 13:58:29, Time Taken: 34.23 seconds
# Epoch 71/200, Start Time: 13:58:29
# Epoch 71/200, End Time: 13:59:03, Time Taken: 34.23 seconds
# Epoch 72/200, Start Time: 13:59:03
# Epoch 72/200, End Time: 13:59:37, Time Taken: 34.29 seconds
# Epoch 73/200, Start Time: 13:59:37
# Epoch 73/200, End Time: 14:00:12, Time Taken: 34.31 seconds
# Epoch 74/200, Start Time: 14:00:12
# Epoch 74/200, End Time: 14:00:46, Time Taken: 34.25 seconds
# Epoch 75/200, Start Time: 14:00:46
# Epoch 75/200, End Time: 14:01:20, Time Taken: 34.26 seconds
# Epoch 76/200, Start Time: 14:01:20
# Epoch 76/200, End Time: 14:01:55, Time Taken: 34.27 seconds
# Epoch 77/200, Start Time: 14:01:55
# Epoch 77/200, End Time: 14:02:29, Time Taken: 34.26 seconds
# Epoch 78/200, Start Time: 14:02:29
# Epoch 78/200, End Time: 14:03:03, Time Taken: 34.26 seconds
# Epoch 79/200, Start Time: 14:03:03
# Epoch 79/200, End Time: 14:03:37, Time Taken: 34.27 seconds
# Epoch 80/200, Start Time: 14:03:37
# Epoch 80/200, End Time: 14:04:12, Time Taken: 34.25 seconds
# Epoch 81/200, Start Time: 14:04:12
# Epoch 81/200, End Time: 14:04:46, Time Taken: 34.26 seconds
# Epoch 82/200, Start Time: 14:04:46
# Epoch 82/200, End Time: 14:05:20, Time Taken: 34.30 seconds
# Epoch 83/200, Start Time: 14:05:20
# Epoch 83/200, End Time: 14:05:54, Time Taken: 34.31 seconds
# Epoch 84/200, Start Time: 14:05:54
# Epoch 84/200, End Time: 14:06:29, Time Taken: 34.31 seconds
# Epoch 85/200, Start Time: 14:06:29
# Epoch 85/200, End Time: 14:07:03, Time Taken: 34.30 seconds
# Epoch 86/200, Start Time: 14:07:03
# Epoch 86/200, End Time: 14:07:37, Time Taken: 34.30 seconds
# Epoch 87/200, Start Time: 14:07:37
# Epoch 87/200, End Time: 14:08:12, Time Taken: 34.27 seconds
# Epoch 88/200, Start Time: 14:08:12
# Epoch 88/200, End Time: 14:08:46, Time Taken: 34.32 seconds
# Epoch 89/200, Start Time: 14:08:46
# Epoch 89/200, End Time: 14:09:20, Time Taken: 34.36 seconds
# Epoch 90/200, Start Time: 14:09:20
# Epoch 90/200, End Time: 14:09:55, Time Taken: 34.43 seconds
# Epoch 91/200, Start Time: 14:09:55
# Epoch 91/200, End Time: 14:10:29, Time Taken: 34.39 seconds
# Epoch 92/200, Start Time: 14:10:29
# Epoch 92/200, End Time: 14:11:03, Time Taken: 34.29 seconds
# Epoch 93/200, Start Time: 14:11:03
# Epoch 93/200, End Time: 14:11:38, Time Taken: 34.33 seconds
# Epoch 94/200, Start Time: 14:11:38
# Epoch 94/200, End Time: 14:12:12, Time Taken: 34.31 seconds
# Epoch 95/200, Start Time: 14:12:12
# Epoch 95/200, End Time: 14:12:46, Time Taken: 34.28 seconds
# Epoch 96/200, Start Time: 14:12:46
# Epoch 96/200, End Time: 14:13:21, Time Taken: 34.26 seconds
# Epoch 97/200, Start Time: 14:13:21
# Epoch 97/200, End Time: 14:13:55, Time Taken: 34.34 seconds
# Epoch 98/200, Start Time: 14:13:55
# Epoch 98/200, End Time: 14:14:29, Time Taken: 34.36 seconds
# Epoch 99/200, Start Time: 14:14:29
# Epoch 99/200, End Time: 14:15:04, Time Taken: 34.27 seconds
# Epoch 100/200, Start Time: 14:15:04
# Epoch 100/200, End Time: 14:15:38, Time Taken: 34.40 seconds
# Epoch 101/200, Start Time: 14:15:38
# Epoch 101/200, End Time: 14:16:12, Time Taken: 34.30 seconds
# Epoch 102/200, Start Time: 14:16:12
# Epoch 102/200, End Time: 14:16:47, Time Taken: 34.29 seconds
# Epoch 103/200, Start Time: 14:16:47
# Epoch 103/200, End Time: 14:17:21, Time Taken: 34.42 seconds
# Epoch 104/200, Start Time: 14:17:21
# Epoch 104/200, End Time: 14:17:55, Time Taken: 34.31 seconds
# Epoch 105/200, Start Time: 14:17:55
# Epoch 105/200, End Time: 14:18:30, Time Taken: 34.32 seconds
# Epoch 106/200, Start Time: 14:18:30
# Epoch 106/200, End Time: 14:19:04, Time Taken: 34.29 seconds
# Epoch 107/200, Start Time: 14:19:04
# Epoch 107/200, End Time: 14:19:38, Time Taken: 34.33 seconds
# Epoch 108/200, Start Time: 14:19:38
# Epoch 108/200, End Time: 14:20:13, Time Taken: 34.37 seconds
# Epoch 109/200, Start Time: 14:20:13
# Epoch 109/200, End Time: 14:20:47, Time Taken: 34.35 seconds
# Epoch 110/200, Start Time: 14:20:47
# Epoch 110/200, End Time: 14:21:21, Time Taken: 34.29 seconds
# Epoch 111/200, Start Time: 14:21:21
# Epoch 111/200, End Time: 14:21:56, Time Taken: 34.36 seconds
# Epoch 112/200, Start Time: 14:21:56
# Epoch 112/200, End Time: 14:22:30, Time Taken: 34.37 seconds
# Epoch 113/200, Start Time: 14:22:30
# Epoch 113/200, End Time: 14:23:04, Time Taken: 34.33 seconds
# Epoch 114/200, Start Time: 14:23:04
# Epoch 114/200, End Time: 14:23:39, Time Taken: 34.33 seconds
# Epoch 115/200, Start Time: 14:23:39
# Epoch 115/200, End Time: 14:24:13, Time Taken: 34.30 seconds
# Epoch 116/200, Start Time: 14:24:13
# Epoch 116/200, End Time: 14:24:47, Time Taken: 34.38 seconds
# Epoch 117/200, Start Time: 14:24:47
# Epoch 117/200, End Time: 14:25:22, Time Taken: 34.28 seconds
# Epoch 118/200, Start Time: 14:25:22
# Epoch 118/200, End Time: 14:25:56, Time Taken: 34.29 seconds
# Epoch 119/200, Start Time: 14:25:56
# Epoch 119/200, End Time: 14:26:30, Time Taken: 34.30 seconds
# Epoch 120/200, Start Time: 14:26:30
# Epoch 120/200, End Time: 14:27:04, Time Taken: 34.29 seconds
# Epoch 121/200, Start Time: 14:27:04
# Epoch 121/200, End Time: 14:27:39, Time Taken: 34.29 seconds
# Epoch 122/200, Start Time: 14:27:39
# Epoch 122/200, End Time: 14:28:13, Time Taken: 34.29 seconds
# Epoch 123/200, Start Time: 14:28:13
# Epoch 123/200, End Time: 14:28:47, Time Taken: 34.32 seconds
# Epoch 124/200, Start Time: 14:28:47
# Epoch 124/200, End Time: 14:29:22, Time Taken: 34.39 seconds
# Epoch 125/200, Start Time: 14:29:22
# Epoch 125/200, End Time: 14:29:56, Time Taken: 34.47 seconds
# Epoch 126/200, Start Time: 14:29:56
# Epoch 126/200, End Time: 14:30:31, Time Taken: 34.42 seconds
# Epoch 127/200, Start Time: 14:30:31
# Epoch 127/200, End Time: 14:31:05, Time Taken: 34.38 seconds
# Epoch 128/200, Start Time: 14:31:05
# Epoch 128/200, End Time: 14:31:39, Time Taken: 34.36 seconds
# Epoch 129/200, Start Time: 14:31:39
# Epoch 129/200, End Time: 14:32:14, Time Taken: 34.40 seconds
# Epoch 130/200, Start Time: 14:32:14
# Epoch 130/200, End Time: 14:32:48, Time Taken: 34.35 seconds
# Epoch 131/200, Start Time: 14:32:48
# Epoch 131/200, End Time: 14:33:23, Time Taken: 34.54 seconds
# Epoch 132/200, Start Time: 14:33:23
# Epoch 132/200, End Time: 14:33:57, Time Taken: 34.51 seconds
# Epoch 133/200, Start Time: 14:33:57
# Epoch 133/200, End Time: 14:34:32, Time Taken: 34.46 seconds
# Epoch 134/200, Start Time: 14:34:32
# Epoch 134/200, End Time: 14:35:06, Time Taken: 34.37 seconds
# Epoch 135/200, Start Time: 14:35:06
# Epoch 135/200, End Time: 14:35:40, Time Taken: 34.41 seconds
# Epoch 136/200, Start Time: 14:35:40
# Epoch 136/200, End Time: 14:36:15, Time Taken: 34.41 seconds
# Epoch 137/200, Start Time: 14:36:15
# Epoch 137/200, End Time: 14:36:49, Time Taken: 34.32 seconds
# Epoch 138/200, Start Time: 14:36:49
# Epoch 138/200, End Time: 14:37:24, Time Taken: 34.35 seconds
# Epoch 139/200, Start Time: 14:37:24
# Epoch 139/200, End Time: 14:37:58, Time Taken: 34.35 seconds
# Epoch 140/200, Start Time: 14:37:58
# Epoch 140/200, End Time: 14:38:32, Time Taken: 34.33 seconds
# Epoch 141/200, Start Time: 14:38:32
# Epoch 141/200, End Time: 14:39:06, Time Taken: 34.27 seconds
# Epoch 142/200, Start Time: 14:39:06
# Epoch 142/200, End Time: 14:39:41, Time Taken: 34.30 seconds
# Epoch 143/200, Start Time: 14:39:41
# Epoch 143/200, End Time: 14:40:15, Time Taken: 34.26 seconds
# Epoch 144/200, Start Time: 14:40:15
# Epoch 144/200, End Time: 14:40:49, Time Taken: 34.23 seconds
# Epoch 145/200, Start Time: 14:40:49
# Epoch 145/200, End Time: 14:41:24, Time Taken: 34.26 seconds
# Epoch 146/200, Start Time: 14:41:24
# Epoch 146/200, End Time: 14:41:58, Time Taken: 34.25 seconds
# Epoch 147/200, Start Time: 14:41:58
# Epoch 147/200, End Time: 14:42:32, Time Taken: 34.25 seconds
# Epoch 148/200, Start Time: 14:42:32
# Epoch 148/200, End Time: 14:43:06, Time Taken: 34.26 seconds
# Epoch 149/200, Start Time: 14:43:06
# Epoch 149/200, End Time: 14:43:41, Time Taken: 34.26 seconds
# Epoch 150/200, Start Time: 14:43:41
# Epoch 150/200, End Time: 14:44:15, Time Taken: 34.26 seconds
# Epoch 151/200, Start Time: 14:44:15
# Epoch 151/200, End Time: 14:44:49, Time Taken: 34.26 seconds
# Epoch 152/200, Start Time: 14:44:49
# Epoch 152/200, End Time: 14:45:23, Time Taken: 34.22 seconds
# Epoch 153/200, Start Time: 14:45:23
# Epoch 153/200, End Time: 14:45:58, Time Taken: 34.25 seconds
# Epoch 154/200, Start Time: 14:45:58
# Epoch 154/200, End Time: 14:46:32, Time Taken: 34.25 seconds
# Epoch 155/200, Start Time: 14:46:32
# Epoch 155/200, End Time: 14:47:06, Time Taken: 34.24 seconds
# Epoch 156/200, Start Time: 14:47:06
# Epoch 156/200, End Time: 14:47:40, Time Taken: 34.19 seconds
# Epoch 157/200, Start Time: 14:47:40
# Epoch 157/200, End Time: 14:48:14, Time Taken: 34.20 seconds
# Epoch 158/200, Start Time: 14:48:14
# Epoch 158/200, End Time: 14:48:49, Time Taken: 34.23 seconds
# Epoch 159/200, Start Time: 14:48:49
# Epoch 159/200, End Time: 14:49:23, Time Taken: 34.23 seconds
# Epoch 160/200, Start Time: 14:49:23
# Epoch 160/200, End Time: 14:49:57, Time Taken: 34.23 seconds
# Epoch 161/200, Start Time: 14:49:57
# Epoch 161/200, End Time: 14:50:31, Time Taken: 34.20 seconds
# Epoch 162/200, Start Time: 14:50:31
# Epoch 162/200, End Time: 14:51:06, Time Taken: 34.23 seconds
# Epoch 163/200, Start Time: 14:51:06
# Epoch 163/200, End Time: 14:51:40, Time Taken: 34.22 seconds
# Epoch 164/200, Start Time: 14:51:40
# Epoch 164/200, End Time: 14:52:14, Time Taken: 34.22 seconds
# Epoch 165/200, Start Time: 14:52:14
# Epoch 165/200, End Time: 14:52:48, Time Taken: 34.20 seconds
# Epoch 166/200, Start Time: 14:52:48
# Epoch 166/200, End Time: 14:53:22, Time Taken: 34.17 seconds
# Epoch 167/200, Start Time: 14:53:22
# Epoch 167/200, End Time: 14:53:57, Time Taken: 34.21 seconds
# Epoch 168/200, Start Time: 14:53:57
# Epoch 168/200, End Time: 14:54:31, Time Taken: 34.22 seconds
# Epoch 169/200, Start Time: 14:54:31
# Epoch 169/200, End Time: 14:55:05, Time Taken: 34.20 seconds
# Epoch 170/200, Start Time: 14:55:05
# Epoch 170/200, End Time: 14:55:39, Time Taken: 34.22 seconds
# Epoch 171/200, Start Time: 14:55:39
# Epoch 171/200, End Time: 14:56:13, Time Taken: 34.21 seconds
# Epoch 172/200, Start Time: 14:56:13
# Epoch 172/200, End Time: 14:56:48, Time Taken: 34.23 seconds
# Epoch 173/200, Start Time: 14:56:48
# Epoch 173/200, End Time: 14:57:22, Time Taken: 34.23 seconds
# Epoch 174/200, Start Time: 14:57:22
# Epoch 174/200, End Time: 14:57:56, Time Taken: 34.23 seconds
# Epoch 175/200, Start Time: 14:57:56
# Epoch 175/200, End Time: 14:58:30, Time Taken: 34.23 seconds
# Epoch 176/200, Start Time: 14:58:30
# Epoch 176/200, End Time: 14:59:05, Time Taken: 34.22 seconds
# Epoch 177/200, Start Time: 14:59:05
# Epoch 177/200, End Time: 14:59:39, Time Taken: 34.23 seconds
# Epoch 178/200, Start Time: 14:59:39
# Epoch 178/200, End Time: 15:00:13, Time Taken: 34.22 seconds
# Epoch 179/200, Start Time: 15:00:13
# Epoch 179/200, End Time: 15:00:47, Time Taken: 34.22 seconds
# Epoch 180/200, Start Time: 15:00:47
# Epoch 180/200, End Time: 15:01:21, Time Taken: 34.18 seconds
# Epoch 181/200, Start Time: 15:01:21
# Epoch 181/200, End Time: 15:01:56, Time Taken: 34.22 seconds
# Epoch 182/200, Start Time: 15:01:56
# Epoch 182/200, End Time: 15:02:30, Time Taken: 34.22 seconds
# Epoch 183/200, Start Time: 15:02:30
# Epoch 183/200, End Time: 15:03:04, Time Taken: 34.24 seconds
# Epoch 184/200, Start Time: 15:03:04
# Epoch 184/200, End Time: 15:03:38, Time Taken: 34.25 seconds
# Epoch 185/200, Start Time: 15:03:38
# Epoch 185/200, End Time: 15:04:13, Time Taken: 34.22 seconds
# Epoch 186/200, Start Time: 15:04:13
# Epoch 186/200, End Time: 15:04:47, Time Taken: 34.23 seconds
# Epoch 187/200, Start Time: 15:04:47
# Epoch 187/200, End Time: 15:05:21, Time Taken: 34.23 seconds
# Epoch 188/200, Start Time: 15:05:21
# Epoch 188/200, End Time: 15:05:55, Time Taken: 34.21 seconds
# Epoch 189/200, Start Time: 15:05:55
# Epoch 189/200, End Time: 15:06:29, Time Taken: 34.21 seconds
# Epoch 190/200, Start Time: 15:06:29
# Epoch 190/200, End Time: 15:07:04, Time Taken: 34.21 seconds
# Epoch 191/200, Start Time: 15:07:04
# Epoch 191/200, End Time: 15:07:38, Time Taken: 34.24 seconds
# Epoch 192/200, Start Time: 15:07:38
# Epoch 192/200, End Time: 15:08:12, Time Taken: 34.22 seconds
# Epoch 193/200, Start Time: 15:08:12
# Epoch 193/200, End Time: 15:08:46, Time Taken: 34.19 seconds
# Epoch 194/200, Start Time: 15:08:46
# Epoch 194/200, End Time: 15:09:21, Time Taken: 34.22 seconds
# Epoch 195/200, Start Time: 15:09:21
# Epoch 195/200, End Time: 15:09:55, Time Taken: 34.23 seconds
# Epoch 196/200, Start Time: 15:09:55
# Epoch 196/200, End Time: 15:10:29, Time Taken: 34.23 seconds
# Epoch 197/200, Start Time: 15:10:29
# Epoch 197/200, End Time: 15:11:03, Time Taken: 34.23 seconds
# Epoch 198/200, Start Time: 15:11:03
# Epoch 198/200, End Time: 15:11:37, Time Taken: 34.24 seconds
# Epoch 199/200, Start Time: 15:11:37
# Epoch 199/200, End Time: 15:12:12, Time Taken: 34.21 seconds
# Epoch 200/200, Start Time: 15:12:12
# Epoch 200/200, End Time: 15:12:46, Time Taken: 34.24 seconds
# Total Time Taken for 200 epochs: 6867.23 seconds

# %%
generator.save("generator.keras")

# %%
generator = tf.keras.models.load_model('generator.keras')
# Out:
# 2024-03-26 19:37:16.008138: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 19:37:16.008398: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 19:37:16.008595: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 19:37:16.077408: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 19:37:16.077636: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 19:37:16.077839: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-26 19:37:16.077994: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4282 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
import gc
gc.collect()

# %% [markdown]
# ## **4. Results**

# %%
y = generator( test_x[0:10] ).numpy()
# Out:
# 2024-03-26 19:37:20.943879: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907

# %%
for i in range(len(test_x)):
  plt.figure(figsize=(10,10))
  or_image = plt.subplot(3,3,1)
  or_image.set_title('Grayscale Input', fontsize=16)
  plt.imshow( test_x[i].reshape((120,120)) , cmap='gray' )

  in_image = plt.subplot(3,3,2)    
  image = Image.fromarray( ( y[i] * 255 ).astype( 'uint8' ) ).resize( ( 1024 , 1024 ) )
  image = np.asarray( image )
  in_image.set_title('Colorized Output', fontsize=16)
  plt.imshow( image )

  ou_image = plt.subplot(3,3,3)
  image = Image.fromarray( ( test_y[i] * 255 ).astype( 'uint8' ) ).resize( ( 1024 , 1024 ) )
  ou_image.set_title('Ground Truth', fontsize=16)
  plt.imshow( image )

  plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 8
#       5 plt.imshow( test_x[i].reshape((120,120)) , cmap='gray' )
#       7 in_image = plt.subplot(3,3,2)
# ----> 8 image = Image.fromarray( ( y[i] * 255 ).astype( 'uint8' ) ).resize( ( 1024 , 1024 ) )
#       9 image = np.asarray( image )
#      10 in_image.set_title('Colorized Output', fontsize=16)
#
# IndexError: index 10 is out of bounds for axis 0 with size 10
